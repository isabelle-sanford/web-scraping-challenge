# %%
from splinter import Browser
from bs4 import BeautifulSoup

executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = "https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest"
browser.visit(url)

# %%
soup = BeautifulSoup(browser.html, 'html.parser')

soup.find_all('div', class_="react_grid_list grid_list_container")
# Out:
# [<div class="react_grid_list grid_list_container" data-react-cache-id="GridListPage-0" data-react-class="GridListPage" data-react-props='{"left_column":false,"class_name":"","default_view":"list_view","model":"news_items","view_toggle":false,"search":"true","list_item":"News","title":"News","categories":["19,165,184,204"],"order":"publish_date desc,created_at desc","no_items_text":"There are no items matching these criteria.","site_title":"NASA’s Mars Exploration Program ","short_title":"Mars","site_share_image":"/system/site_config_values/meta_share_images/1_mars-nasa-gov.jpg","per_page":null,"filters":"[ [ \"date\", [ [ \"2021\", \"2021\" ], [ \"2020\", \"2020\" ], [ \"2019\", \"2019\" ], [ \"2018\", \"2018\" ], [ \"2017\", \"2017\" ], [ \"2016\", \"2016\" ], [ \"2015\", \"2015\" ], [ \"2014\", \"2014\" ], [ \"2013\", \"2013\" ], [ \"2012\", \"2012\" ], [ \"2011\", \"2011\" ], [ \"2010\", \"2010\" ], [ \"2009\", \"2009\" ], [ \"2008\", \"2008\" ], [ \"2007\", \"2007\" ], [ \"2006\"
# ...

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
driver = webdriver.Chrome()
url = "https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest"
driver.get(url)
soup = BeautifulSoup(driver.page_source, 'html.parser')
driver.quit()
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\Public\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      71             cmd.extend(self.command_line_args())
# ---> 72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
#
# C:\Users\Public\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     853
# --> 854             self._execute_child(args, executable, preexec_fn, close_fds,
#     855                                 pass_fds, cwd, env,
#
# ...

# %%
# Dependencies
from bs4 import BeautifulSoup
import requests

# %%
# URL of page to be scraped
url = 'https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest'

# %%
# Retrieve page with the requests module
headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36'}
response = requests.get(url, headers=headers)

# %%
response.headers
# Out:
# {'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Date': 'Fri, 08 Jan 2021 02:48:13 GMT', 'Server': 'Apache', 'Cache-Control': 'max-age=900, public, public', 'X-Frame-Options': 'ALLOWALL', 'X-Runtime': '0.196391', 'X-Request-Id': 'edb62f29-d7d5-4a04-9695-93121d70761c', 'X-Powered-By': 'Phusion Passenger', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'ETag': 'W/"500f1887218dcc26d767bbbcd49e09da"', 'Status': '200 OK', 'X-Cache': 'Hit from cloudfront', 'Via': '1.1 4d0ecb5905192435c3fd204705c9fc24.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'DEN50-C2', 'X-Amz-Cf-Id': 'Lg9Dbm9H_3xf5Aav5sUzTE3Kf50S6Ru8LnrsjFIPTPVUIS-ycSkxKg==', 'Age': '151'}

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Examine the results, then determine element that contains sought info
#print(soup.prettify())

# %%
soup.find_all('div', class_="react_grid_list grid_list_container")
# Out:
# [<div class="react_grid_list grid_list_container" data-react-cache-id="GridListPage-0" data-react-class="GridListPage" data-react-props='{"left_column":false,"class_name":"","default_view":"list_view","model":"news_items","view_toggle":false,"search":"true","list_item":"News","title":"News","categories":["19,165,184,204"],"order":"publish_date desc,created_at desc","no_items_text":"There are no items matching these criteria.","site_title":"NASA’s Mars Exploration Program ","short_title":"Mars","site_share_image":"/system/site_config_values/meta_share_images/1_mars-nasa-gov.jpg","per_page":null,"filters":"[ [ \"date\", [ [ \"2021\", \"2021\" ], [ \"2020\", \"2020\" ], [ \"2019\", \"2019\" ], [ \"2018\", \"2018\" ], [ \"2017\", \"2017\" ], [ \"2016\", \"2016\" ], [ \"2015\", \"2015\" ], [ \"2014\", \"2014\" ], [ \"2013\", \"2013\" ], [ \"2012\", \"2012\" ], [ \"2011\", \"2011\" ], [ \"2010\", \"2010\" ], [ \"2009\", \"2009\" ], [ \"2008\", \"2008\" ], [ \"2007\", \"2007\" ], [ \"2006\"
# ...

# %%
# Find the current news titles 
titles = soup.find_all('div', class_="content_title")
# Find the news paragraphs
paras = soup.find_all('div', class_="article_teaser_body")
# Assign the text to variables, and with text only
print(titles)
print(paras)
# Out:
# [<div class="content_title">
# <a href="/news/8716/nasa-to-broadcast-mars-2020-perseverance-launch-prelaunch-activities/">
# NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities
# </a>
# </div>, <div class="content_title">
# <a href="/news/8695/the-launch-is-approaching-for-nasas-next-mars-rover-perseverance/">
# The Launch Is Approaching for NASA's Next Mars Rover, Perseverance
# </a>
# </div>, <div class="content_title">
# <a href="/news/8692/nasa-to-hold-mars-2020-perseverance-rover-launch-briefing/">
# NASA to Hold Mars 2020 Perseverance Rover Launch Briefing
# </a>
# </div>, <div class="content_title">
# <a href="/news/8659/alabama-high-school-student-names-nasas-mars-helicopter/">
# Alabama High School Student Names NASA's Mars Helicopter
# </a>
# </div>, <div class="content_title">
# <a href="/news/8645/mars-helicopter-attached-to-nasas-perseverance-rover/">
# Mars Helicopter Attached to NASA's Perseverance Rover
# </a>
# </div>, <div class="content_title">
# ...

# %%
response_test = requests.get("https://mars.nasa.gov/api/v1/news_items/").json()

# %%
for item in response_test["items"]:
    print(item["title"])
# Out:
# Deadline Nears For Student Contest to Name NASA's Next Mars Rover
# Next NASA Mars Mission Rescheduled For 2011
# Site List Narrows For NASA's Next Mars Landing
# NASA Invites Students to Name New Mars Rover
# Mars Rovers Sharpen Questions About Livable Conditions
# Astronomers Monitor Asteroid to Pass Near Mars
# Spectrometer on NASA Orbiter Maps Minerals at Possible Landing Sites
# NASA Orbiter Provides Color Views of Mars Landing Site Candidates
# Keeping it Cool (...or Warm!)
# The Games We Play
# The Politics of Landing
# A Precious Ring
# So Happy Together
# A Rough, Tough, Red Planet Rock Hound
# High-Flying Test Rides

# %%
url = "http://api.worldbank.org/v2/"
api_format = "json"

# Get country information in JSON format
countries_response = requests.get(f"{url}countries?format={api_format}").json()

# %%
"filters":"[ [ \"date\", [ [ \"2021\", \"2021\" ], [ \"2020\", \"2020\" ], [ \"2019\", \"2019\" ], [ \"2018\", \"2018\" ], [ \"2017\", \"2017\" ], [ \"2016\", \"2016\" ], [ \"2015\", \"2015\" ], [ \"2014\", \"2014\" ], [ \"2013\", \"2013\" ], [ \"2012\", \"2012\" ], [ \"2011\", \"2011\" ], [ \"2010\", \"2010\" ], [ \"2009\", \"2009\" ], [ \"2008\", \"2008\" ], [ \"2007\", \"2007\" ], [ \"2006\", \"2006\" ], [ \"2005\", \"2005\" ], [ \"2004\", \"2004\" ], [ \"2003\", \"2003\" ], [ \"2002\", \"2002\" ], [ \"2001\", \"2001\" ], [ \"2000\", \"2000\" ] ], [ \"Latest\", \"\" ], false, false ], [ \"categories\", [ [ \"Feature Stories\", 165 ], [ \"Press Releases\", 19 ], [ \"Spotlights\", 184 ], [ \"Status Reports\", 204 ] ], [ \"All Categories\", \"\" ], false, false ] ]","conditions":null,"scope_in_title":true,"options":{"blank_scope":"Latest"},

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang=\'en\' xml:lang=\'en\' xmlns=\'http://www.w3.org/1999/xhtml\'>\n<head>\n<meta content=\'text/html; charset=utf-8\' http-equiv=\'Content-Type\'>\n<!-- Always force latest IE rendering engine or request Chrome Frame -->\n<meta content=\'IE=edge,chrome=1\' http-equiv=\'X-UA-Compatible\'>\n<!-- Responsiveness -->\n<meta content=\'width=device-width, initial-scale=1.0\' name=\'viewport\'>\n<!-- Favicon -->\n<link href=\'/apple-touch-icon.png\' rel=\'apple-touch-icon\' sizes=\'180x180\'>\n<link href=\'/favicon-32x32.png\' rel=\'icon\' sizes=\'32x32\' type=\'image/png\'>\n<link href=\'/favicon-16x16.png\' rel=\'icon\' sizes=\'16x16\' type=\'image/png\'>\n<link href=\'/manifest.json\' rel=\'manifest\'>\n<link color=\'#e48b55\' href=\'/safari-pinned-tab.svg\' rel=\'mask-icon\'>\n<meta content=\'#000000\' name=\'theme-color\'>\n\n<meta name="csrf-param" content="authenticity_token" />\n<meta name="csrf-token" content="1VtVz3KmnWroth51Cgq945VXA8eWplYART4jotGwdv/THxs
# ...
